# %%
import os
os.getcwd()

# %%
# %run ../scripts/simple_preprocess.py

# %%
# %run ../scripts/text_summarization.py

# %%
# %run ../scripts/preprocess.py

# %%
# %run ../scripts/tf_idf.py

# %%
# %run ../scripts/cluster_trend.py

# %%
# %run ../scripts/topic_model.py

# %%
# %run ../scripts/visualization.py
